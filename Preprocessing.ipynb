# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd

# %%
dataset = pd.read_csv("Datasets\Dataset_python.csv")

# %%
dataset.head()
# Out:
#    Unnamed: 0 Country name  Year  Life Ladder  Log GDP per capita  \
# 0           1  Afghanistan  2008     3.723590            7.168690
# 1           2  Afghanistan  2009     4.401778            7.333790
# 2           3  Afghanistan  2010     4.758381            7.386629
# 3           4  Afghanistan  2011     3.831719            7.415019
# 4           5  Afghanistan  2012     3.782938            7.517126
#
#    Social support  Healthy life expectancy at birth  \
# 0        0.450662                         50.799999
# 1        0.552308                         51.200001
# 2        0.539075                         51.599998
# 3        0.521104                         51.919998
# 4        0.520637                         52.240002
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                      0.718114    0.177889                   0.881686
# 1                      0.678896    0.200178                   0.850035
# ...

# %%
dataset_1 = dataset.loc[dataset['Year'].isin([2017,2018])]

# %%
(dataset_1["Year"]== 2018).sum()
# Out:
# 136

# %%
(dataset_1["Year"]== 2017).sum()
# Out:
# 147

# %%
((dataset_1["Year"]== 2017)!=(dataset_1["Year"]== 2018))
# Out:
# 283

# %%
df_1 = dataset_1.groupby("Country name")
df_2 = df_1.filter(lambda x: len(x)>1)

# %%
(df_2["Year"]== 2018).sum()
# Out:
# 131

# %%
(df_2["Year"]== 2017).sum()
# Out:
# 131

# %%
df_2.describe()
# Out:
#         Unnamed: 0         Year  Life Ladder  Log GDP per capita  \
# count   262.000000   262.000000   262.000000          251.000000
# mean    858.019084  2017.500000     5.506385            9.291332
# std     491.191494     0.500957     1.115067            1.162028
# min      10.000000  2017.000000     2.661718            6.623784
# 25%     443.000000  2017.000000     4.659800            8.483234
# 50%     872.500000  2017.500000     5.480884            9.481223
# 75%    1277.500000  2018.000000     6.317309           10.210910
# max    1704.000000  2018.000000     7.858107           11.454002
#
#        Social support  Healthy life expectancy at birth  \
# count      261.000000                        258.000000
# mean         0.811945                         64.627632
# std          0.114333                          6.750827
# min          0.435879                         47.700001
# 25%          0.739956                         59.200001
# ...

# %%
df_2.isnan
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-cc8b84f0812f> in <module>()
# ----> 1 df_2.isnan
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'isnan'

# %%
df_2.isnull().sum()
# Out:
# Unnamed: 0                                                    0
# Country name                                                  0
# Year                                                          0
# Life Ladder                                                   0
# Log GDP per capita                                           11
# Social support                                                1
# Healthy life expectancy at birth                              4
# Freedom to make life choices                                  1
# Generosity                                                   13
# Perceptions of corruption                                    15
# Positive affect                                               2
# Negative affect                                               2
# Confidence in national government                            23
# Democratic Quality                                          131
# Delivery Quality                                            131
# ...

# %%
df_2.drop("Democratic Quality", axis =1 ,inplace=True)
df_2.drop("Delivery Quality",axis=1,inplace= True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-aa7641ac8a77> in <module>()
# ----> 1 df_2.drop("Democratic Quality", axis =1 ,inplace=True)
#       2 df_2.drop("Delivery Quality",axis=1,inplace= True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# ...

# %%
df_2.head()
# Out:
#     Unnamed: 0 Country name  Year  Life Ladder  Log GDP per capita  \
# 9           10  Afghanistan  2017     2.661718            7.497755
# 10          11  Afghanistan  2018     2.694303            7.494588
# 20          21      Albania  2017     4.639548            9.376145
# 21          22      Albania  2018     5.004403            9.412399
# 27          28      Algeria  2017     5.248912            9.540639
#
#     Social support  Healthy life expectancy at birth  \
# 9         0.490880                         52.799999
# 10        0.507516                         52.599998
# 20        0.637698                         68.400002
# 21        0.683592                         68.699997
# 27        0.806754                         65.699997
#
#     Freedom to make life choices  Generosity  Perceptions of corruption  \
# 9                       0.427011   -0.112198                   0.954393
# 10                      0.373536   -0.084888                   0.927606
# ...

# %%
import sklearn
from sklearn.preprocessing import Imputer
import numpy as np

# %%
imp= Imputer(missing_values=np.nan, strategy ="mean")
imp.fit(df_2[,2:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-ef5a1982a96b> in <module>()
#       1 imp= Imputer(missing_values=np.nan, strategy ="mean")
# ----> 2 imp.fit(df_2)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\imputation.py in fit(self, X, y)
#     153         if self.axis == 0:
#     154             X = check_array(X, accept_sparse='csc', dtype=np.float64,
# --> 155                             force_all_finite=False)
#     156
#     157             if sparse.issparse(X):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# ...

# %%
df_3=df_2.fillna(df_2.mean())

# %%
df_3.isnull().sum()
# Out:
# Unnamed: 0                                                  0
# Country name                                                0
# Year                                                        0
# Life Ladder                                                 0
# Log GDP per capita                                          0
# Social support                                              0
# Healthy life expectancy at birth                            0
# Freedom to make life choices                                0
# Generosity                                                  0
# Perceptions of corruption                                   0
# Positive affect                                             0
# Negative affect                                             0
# Confidence in national government                           0
# Standard deviation of ladder by country-year                0
# Standard deviation/Mean of ladder by country-year           0
# ...

# %%
df_3.to_csv("Dataset_Cleaned_Python.csv")
